# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

df = pd.read_csv(R"C:\Users\TAJ\Desktop\world_economic_report\WorldBank.xlsx")

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined
